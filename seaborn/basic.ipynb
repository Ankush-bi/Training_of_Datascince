# %%
! pip3 install seaborn

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.scatter(df['tip'],df['total_bill'])
plt.show()

# %%
sns.scatterplot(x='tip',y='total_bill',data= df)
plt.show()

# %%
plt.hist(df['total_bill'])
plt.show()

# %%
sns.histplot(df['total_bill'])
plt.show()

# %%
sns.kdeplot(df['total_bill'])
plt.show(
    
)

# %%
sns.regplot(x='tip',y='total_bill',data= df)
plt.show()

# %%
sns.relplot(x='tip',y='total_bill',data= df, hue = 'smoker')
plt.show()

# %%
sns.relplot(x='tip',y='total_bill',data= df,hue = 'time')
plt.show()

# %%
sns.relplot(x='tip',y='total_bill',data= df,hue = 'time',style='smoker')
plt.show()

# %%
sns.relplot(x='tip',y='total_bill',data= df,hue = 'time',col='day')
plt.show()

# %%
sns.relplot(x='tip',y='total_bill',data= df,hue = 'time',row='day')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data = df,kind = 'boxen')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data = df,kind = 'strip')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data = df,kind = 'box')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data = df,kind = 'bar')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data = df,kind = 'swarm')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data = df,kind = 'violin')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data = df,kind = 'point')
plt.show()

# %%
sns.boxenplot(x='total_bill',data=df)
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.boxenplot(df['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>
