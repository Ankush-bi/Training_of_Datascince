# %%
dic = {
    "ashish":324,
    "ankush":234,
    "bittu":444
}
dic["ashisha"]=234564567
print(dic)

# %%
dic = {
    "ashish":324,
    "ankush":234,
    "bittu":444
}
dic.update({"ashish":23456})
print(dic)

# %%
dic = {
    "ashish":324,
    "ankush":234,
    "bittu":444
}
# get = dic.get()
print(dic.get("ashish"))

# %%
dic = {
    "ashish":324,
    "ankush":234,
    "bittu":444
}
name=input()
print(dic[name])

# %%
list = []
for i in list:
    print(i)

# %%
lst = []
for i in range(1,11):
    value = input("enter the futies")
    lst.append(value)
print(lst)

# %%
a = int(input("enter number"))
b = int(input("enter number"))
c = int(input("enter number"))

if a > b and  c > a:
    print(f"num {a} is gretor than {b} and {c}")
elif b > c:
     print(f"num {b} is gretor than {a} and {c}")
  
else:
     print(f"num {c} is gretor than {b} and {a}")
