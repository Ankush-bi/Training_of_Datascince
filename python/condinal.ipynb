# %%
age = int(input("what is your age :-"))

if age >= 18 :
    print("YOU CAN VOTE")

else:
    print("YOU CAN NOT VOTE")

# %%
print("Hii")
print("bittu")

# %%
num = int(input("Enter a number :-"))
if num>=0:
    print("positive")
elif num <=0:
    print("negative")
else:
    print("zero")

# %%
#Accept a year and check if it is a leap year or not
year = int(input("Enter a year :-"))
if year %100 == 0 and year %400 != 0:
    print(f"{year} is a leap year")
elif year %100 == 0 and year % 4 == 0:
    print(f"{year} is a leap year")
else:
    print(f"{year} is not a leap year")

# %%
mark = int(input("Enter your number"))
if 90<= mark <= 100:
    print("you are top the college")
elif 70<= mark <= 80:
    print("Grade B")
elif 70<= mark <= 60:
    print("Grade")

elif 50<= mark <= 40:
      print("Grade D")

else :
     print("you are fail")

# %%
mark = int(input("Enter you marks"))
att  = int(input("enter your att:"))
if mark>=75:
    if att>= 78:
        print("you set the class")

    else:
        print("you cant to set ")
    pass #

elif mark>=60:
    if att>= 78:
        print("you set the class")

    else:
        print("you cant to set ")


else:
    print("you are fail")

# %%
for x in range(1,6):
   print((x),end =" ")

# %%
for x in range(1,5):
    print(x**2,end=" ")

# %%
for x in range(1,11):
    if(x % 2 == 0):
       print((x),end=" ")

# %%
for x in range(1,11):
    # if(x % 2 == 0):
  print(x % 2 == 0,end=" ")

# %%
sum = 0
for i in range(1,11):
    sum = sum + i
print("sum of number",i)

# %%
name = "python"
for i in reversed(name):
    print(i,end=" ")

# %%
name = "education"
count = 0
for chr in name:
    if chr in"aeiou":
        print(chr)
        count = count + 1
print(count)

# %% [markdown]
# while loop

# %%
num = 10
while num<= 15:
    print(num)
    num += 1

# %%
num = 1
while num<= 5:
    print(num*2)
    num += 1

# %%
num = 1
while num<= 5:
    # print(num**3)
    print(num*num*num)
    num += 1

# %%
i = 1
while i<=10:
    if(i%2!=0):
        print(i)
    i +=1

# %%
num=1
product=1 
while num<=5:
    product=product*num
    num += 1
print(product)
# Out:
# 120
