# %%
import os

# %%
os.getcwdb()
# Out:
# b'/home/user/Desktop/Training/opreting system(os)'

# %%
os.getcwd
# Out:
# <function posix.getcwd()>

# %%
path = r"/home/user/Desktop/Training"
os.listdir(path)
# Out:
# ['Assement',
#  'Project',
#  'Numpy',
#  'opreting system(os)',
#  'GRU',
#  'python',
#  'Pandas',
#  'Machine learning',
#  'GIT and github',
#  'Deep learning',
#  '.git',
#  'ISTM',
#  'Matplotlip',
#  'AWS',
#  'Assignment',
#  '.venv']

# %%
os.mkdir("file")

# %%
os.rmdir("file")
print("folder dlt")
# Out:
# folder dlt

# %%
os.path.isdir(r"/home/user/Desktop/Training/opreting system(os)/basic.ipynb")
# Out:
# False

# %%
os.path.isdir("/home/user/Desktop/Training/opreting system(os)")
# Out:
# True

# %%
os.path.isfile("/home/user/Desktop/Training/opreting system(os)")
# Out:
# False

# %%
os.path.isdir("/home/user/Desktop/Training/opreting system(os)")
# Out:
# True

# %%
#os.path.join(path1,path2)

# %%
#os.p
