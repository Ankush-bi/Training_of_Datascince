# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR

# %%
df = pd.read_csv("/home/user/Desktop/Training/Project/Medical/Data/medical_disease_prediction_10000.csv")
df

# %%
print(df.head())

# %%
print("Shape of Dataset:", df.shape)

# %%
print(df.columns)

# %%
print(df.info())

# %%
print(df.isnull().sum())

# %%
print( df.duplicated().sum())

# %%
df = df.drop_duplicates()

# %%
print( df.duplicated().sum())

# %%
print(df.describe())

# %%
for col in df.columns:
    print("\nColumn:", col)
    print(df[col].unique())

# %%
int_df = df.copy()

# %%
int_df['Gender'] = int_df['Gender'].map({
    'Male':0,
    'Female':1
})

int_df['Smoking'] = int_df['Smoking'].map({
    'No':0,
    'Yes':1
})

int_df['Alcohol'] = int_df['Alcohol'].map({
    'No':0,
    'Yes':1
})

int_df['FamilyHistory'] = int_df['FamilyHistory'].map({
    'No':0,
    'Yes':1
})

# %%
corr_matrix = int_df.corr(numeric_only=True)

print(corr_matrix)

# %%
int_df.to_csv("medical_disease_cleaned.csv",index=False)

# %%
df

# %%
Disease_dict = {
    'Healthy':1, 'Pre-Diabetes':2, 'Hypertension':3, 'Heart Disease':4, 'Diabetes':5
}

df['Disease']=df['Disease'].map(Disease_dict)

# %%
df

# %%
x = df.drop("Disease",axis =1)
y = df["Disease"]

# %%
y

# %%
x

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=42)

# %%
x_test

# %%
x_train

# %%
y_train

# %%
y_test

# %%
print(df["Gender"].head())
print(df["Gender"].dtype)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)

# %% [markdown]
# #  SVM(SVR)

# %%
from sklearn.svm import SVR

# %%
sv=SVR()
sv.fit(x_train,y_train)

# %%
print('SVR test score:-',sv.score(x_test,y_test))
print('SVR train score:-',sv.score(x_train,y_train))
