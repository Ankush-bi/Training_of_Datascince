# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv(r'clean_data.csv')
df
# Out:
#       Unnamed: 0  owner  brand     price  kms_driven  age  power
# 0              0      1    NaN   35000.0     17654.0  3.0  110.0
# 1              1      1    NaN  119900.0     11000.0  4.0  350.0
# 2              2      1    NaN  600000.0       110.0  8.0  675.0
# 3              3      1    NaN   65000.0     16329.0  4.0  180.0
# 4              4      1    NaN   80000.0     10000.0  3.0  150.0
# ...          ...    ...    ...       ...         ...  ...    ...
# 7301        7301      1    NaN   25000.0     48587.0  8.0  150.0
# 7302        7302      1    NaN   35000.0     60000.0  9.0  220.0
# 7303        7303      1    NaN  450000.0      3430.0  4.0  750.0
# 7304        7304      1    NaN  139000.0     21300.0  4.0  400.0
# 7305        7305      1    NaN   80000.0      7127.0  5.0  220.0
#
# [7306 rows x 7 columns]

# %%
df['brand'] = df['brand'].fillna(df['brand'].mean())

# %%
df
# Out:
#       owner  brand     price  kms_driven  age  power
# 0         1    NaN   35000.0     17654.0  3.0  110.0
# 1         1    NaN  119900.0     11000.0  4.0  350.0
# 2         1    NaN  600000.0       110.0  8.0  675.0
# 3         1    NaN   65000.0     16329.0  4.0  180.0
# 4         1    NaN   80000.0     10000.0  3.0  150.0
# ...     ...    ...       ...         ...  ...    ...
# 7301      1    NaN   25000.0     48587.0  8.0  150.0
# 7302      1    NaN   35000.0     60000.0  9.0  220.0
# 7303      1    NaN  450000.0      3430.0  4.0  750.0
# 7304      1    NaN  139000.0     21300.0  4.0  400.0
# 7305      1    NaN   80000.0      7127.0  5.0  220.0
#
# [7306 rows x 6 columns]

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)
df.drop
# Out:
# <bound method DataFrame.drop of       owner  brand     price  kms_driven  age  power
# 0         1    NaN   35000.0     17654.0  3.0  110.0
# 1         1    NaN  119900.0     11000.0  4.0  350.0
# 2         1    NaN  600000.0       110.0  8.0  675.0
# 3         1    NaN   65000.0     16329.0  4.0  180.0
# 4         1    NaN   80000.0     10000.0  3.0  150.0
# ...     ...    ...       ...         ...  ...    ...
# 7301      1    NaN   25000.0     48587.0  8.0  150.0
# 7302      1    NaN   35000.0     60000.0  9.0  220.0
# 7303      1    NaN  450000.0      3430.0  4.0  750.0
# 7304      1    NaN  139000.0     21300.0  4.0  400.0
# 7305      1    NaN   80000.0      7127.0  5.0  220.0
#
# [7306 rows x 6 columns]>

# %%
df.duplicated().sum()
# Out:
# np.int64(11)

# %%
df.isnull().sum()
# Out:
# owner            0
# brand         7306
# price            0
# kms_driven       0
# age              0
# power            0
# dtype: int64

# %%
df['brand'].unique()
# Out:
# array([nan])

# %%
brand_dict = {
    'TVS':1,   'Royal Enfield':2,         'Triumph':3,          'Yamaha':4,
           'Honda':5,            'Hero':6,           'Bajaj':7,          'Suzuki':8,
         'Benelli':9,             'KTM':10,        'Mahindra':11,        'Kawasaki':12,
          'Ducati':13,         'Hyosung':14, 'Harley-Davidson':15,            'Jawa':16,
             'BMW':17,          'Indian':18,         'Rajdoot':19,             'LML':20,
           'Yezdi':21,              'MV':22,           'Ideal':23
              }

df['brand']=df['brand'].map(brand_dict)

# %%
df.to_csv("clean_data.csv")

# %%
x = df.drop(['price'],axis=1)

# %%
y = df[['price']]

# %%
x
# Out:
#       owner  brand  kms_driven  age  power
# 0         1    NaN     17654.0  3.0  110.0
# 1         1    NaN     11000.0  4.0  350.0
# 2         1    NaN       110.0  8.0  675.0
# 3         1    NaN     16329.0  4.0  180.0
# 4         1    NaN     10000.0  3.0  150.0
# ...     ...    ...         ...  ...    ...
# 7301      1    NaN     48587.0  8.0  150.0
# 7302      1    NaN     60000.0  9.0  220.0
# 7303      1    NaN      3430.0  4.0  750.0
# 7304      1    NaN     21300.0  4.0  400.0
# 7305      1    NaN      7127.0  5.0  220.0
#
# [7306 rows x 5 columns]

# %%
y
# Out:
#          price
# 0      35000.0
# 1     119900.0
# 2     600000.0
# 3      65000.0
# 4      80000.0
# ...        ...
# 7301   25000.0
# 7302   35000.0
# 7303  450000.0
# 7304  139000.0
# 7305   80000.0
#
# [7306 rows x 1 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=42)

# %%
x_test
# Out:
#       owner  brand  kms_driven   age  power
# 7062      1    NaN     35000.0   9.0  250.0
# 4553      1    NaN      9066.0   5.0  250.0
# 6505      1    NaN     48000.0  17.0  100.0
# 1918      1    NaN     20222.0   5.0  150.0
# 5227      1    NaN     27167.0   5.0  150.0
# ...     ...    ...         ...   ...    ...
# 2045      1    NaN     98971.0   8.0  150.0
# 527       1    NaN      2881.0   7.0  250.0
# 1783      1    NaN      6517.0   2.0  350.0
# 5065      1    NaN      5222.0   5.0  350.0
# 565       1    NaN      2980.0   6.0  160.0
#
# [1462 rows x 5 columns]

# %%
x_train
# Out:
#       owner  brand  kms_driven  age  power
# 6302      1    NaN     12061.0  4.0  180.0
# 7037      2    NaN     40000.0  7.0  220.0
# 640       1    NaN     28329.0  6.0  110.0
# 6153      2    NaN     10000.0  8.0  220.0
# 1755      1    NaN     26000.0  8.0  150.0
# ...     ...    ...         ...  ...    ...
# 5191      1    NaN     15383.0  2.0  100.0
# 5226      1    NaN     45263.0  6.0  150.0
# 5390      1    NaN     45000.0  6.0  100.0
# 860       1    NaN     14836.0  8.0  150.0
# 7270      1    NaN      2126.0  3.0  250.0
#
# [5844 rows x 5 columns]

# %%
y_test
# Out:
#          price
# 7062  125000.0
# 4553  220000.0
# 6505   16900.0
# 1918   58000.0
# 5227   58000.0
# ...        ...
# 2045   25000.0
# 527   140000.0
# 1783  156000.0
# 5065  118000.0
# 565    36000.0
#
# [1462 rows x 1 columns]

# %%
y_train
# Out:
#          price
# 6302   65000.0
# 7037   49000.0
# 640    32000.0
# 6153   36000.0
# 1755   70000.0
# ...        ...
# 5191   38000.0
# 5226   62000.0
# 5390   30000.0
# 860    40000.0
# 7270  115800.0
#
# [5844 rows x 1 columns]

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((5844, 5), (1462, 5), (5844, 1), (1462, 1))

# %%
print(x_test.isnull().sum())
print(x_train.isnull().sum())
# Out:
# owner            0
# brand         1462
# kms_driven       0
# age              0
# power            0
# dtype: int64
# owner            0
# brand         5844
# kms_driven       0
# age              0
# power            0
# dtype: int64

# %%
x.isnull().sum()
# Out:
# owner            0
# brand         7306
# kms_driven       0
# age              0
# power            0
# dtype: int64

# %% [markdown]
# # # SVM (SVR)

# %%
x.isnull().sum()
# Out:
# owner            0
# brand         7306
# kms_driven       0
# age              0
# power            0
# dtype: int64

# %%
x_train.isnull().sum()
# Out:
# owner            0
# brand         5844
# kms_driven       0
# age              0
# power            0
# dtype: int64

# %%
print(x_train.isnull().sum())
print(x_train.dtypes)
# Out:
# owner            0
# brand         5844
# kms_driven       0
# age              0
# power            0
# dtype: int64
# owner           int64
# brand         float64
# kms_driven    float64
# age           float64
# power         float64
# dtype: object

# %%
x_train['brand'] = x_train['brand'].fillna(x_train['brand'].mean())
x_test['brand'] = x_test['brand'].fillna(x_train['brand'].mean())

# %%
x_train.isnull().sum()
# Out:
# owner            0
# brand         5844
# kms_driven       0
# age              0
# power            0
# dtype: int64

# %%
from sklearn.svm import SVC,SVR
sv=SVR()
sv.fit(x_train,y_train)
pred = sv.predict(x_train)
pred
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[176], line 3
#       1 from sklearn.svm import SVC,SVR
#       2 sv=SVR()
# ----> 3 sv.fit(x_train,y_train)
#       4 pred = sv.predict(x_train)
#       5 pred
#
# File ~/Desktop/Training/Project/Bike_prediction/bike_anand/lib/python3.12/site-packages/sklearn/base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File ~/Desktop/Training/Project/Bike_prediction/bike_anand/lib/python3.12/site-packages/sklearn/svm/_base.py:214, in BaseLibSVM.fit(self, X, y, sample_weight)
#     212     check_consistent_length(X, y)
#     213 else:
# --> 214     X, y = validate_data(
#     215         self,
#     216         X,
#     217         y,
#     218         dtype=np.float64,
#     219         order="C",
#     220         accept_sparse="csr",
#     221         accept_large_sparse=False,
#     222     )
#     224 y = self._validate_targets(y)
#     226 sample_weight = np.asarray(
#     227     [] if sample_weight is None else sample_weight, dtype=np.float64
#     228 )
#
# File ~/Desktop/Training/Project/Bike_prediction/bike_anand/lib/python3.12/site-packages/sklearn/utils/validation.py:3055, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    3053         y = check_array(y, input_name="y", **check_y_params)
#    3054     else:
# -> 3055         X, y = check_X_y(X, y, **check_params)
#    3056     out = X, y
#    3058 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/Desktop/Training/Project/Bike_prediction/bike_anand/lib/python3.12/site-packages/sklearn/utils/validation.py:1327, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1322         estimator_name = _check_estimator_name(estimator)
#    1323     raise ValueError(
#    1324         f"{estimator_name} requires y to be passed, but the target y is None"
#    1325     )
# -> 1327 X = check_array(
#    1328     X,
#    1329     accept_sparse=accept_sparse,
#    1330     accept_large_sparse=accept_large_sparse,
#    1331     dtype=dtype,
#    1332     order=order,
#    1333     copy=copy,
#    1334     force_writeable=force_writeable,
#    1335     ensure_all_finite=ensure_all_finite,
#    1336     ensure_2d=ensure_2d,
#    1337     allow_nd=allow_nd,
#    1338     ensure_min_samples=ensure_min_samples,
#    1339     ensure_min_features=ensure_min_features,
#    1340     estimator=estimator,
#    1341     input_name="X",
#    1342 )
#    1344 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1346 check_consistent_length(X, y)
#
# File ~/Desktop/Training/Project/Bike_prediction/bike_anand/lib/python3.12/site-packages/sklearn/utils/validation.py:1087, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1081     raise ValueError(
#    1082         f"Found array with dim {array.ndim},"
#    1083         f" while dim <= 2 is required{context}."
#    1084     )
#    1086 if ensure_all_finite:
# -> 1087     _assert_all_finite(
#    1088         array,
#    1089         input_name=input_name,
#    1090         estimator_name=estimator_name,
#    1091         allow_nan=ensure_all_finite == "allow-nan",
#    1092     )
#    1094 if copy:
#    1095     if _is_numpy_namespace(xp):
#    1096         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~/Desktop/Training/Project/Bike_prediction/bike_anand/lib/python3.12/site-packages/sklearn/utils/validation.py:137, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     134 if first_pass_isfinite:
#     135     return
# --> 137 _assert_all_finite_element_wise(
#     138     X,
#     139     xp=xp,
#     140     allow_nan=allow_nan,
#     141     msg_dtype=msg_dtype,
#     142     estimator_name=estimator_name,
#     143     input_name=input_name,
#     144 )
#
# File ~/Desktop/Training/Project/Bike_prediction/bike_anand/lib/python3.12/site-packages/sklearn/utils/validation.py:186, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     169 if estimator_name and input_name == "X" and has_nan_error:
#     170     # Improve the error message on how to handle missing values in
#     171     # scikit-learn.
#     172     msg_err += (
#     173         f"\n{estimator_name} does not accept missing values"
#     174         " encoded as NaN natively. For supervised learning, you might want"
#    (...)    184         "#estimators-that-handle-nan-values"
#     185     )
# --> 186 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# SVR does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
pred=sv.predict(x_test)
pred

# %%
print('SVR test score:-',sv.score(x_test,y_test))
print('SVR train score:-',sv.score(x_train,y_train))

# %% [markdown]
# # # SVM (SVC)

# %%
from sklearn.datasets import load_breast_cancer,load_diabetes
x,y=load_breast_cancer(return_X_y=True)
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=42)
from sklearn.svm import SVC
sv=SVC()
sv.fit(x_train,y_train)
print('test score:-',sv.score(x_test,y_test))
print('train score:-',sv.score(x_train,y_train))

# %% [markdown]
# # # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr= LinearRegression()
lr.fit(x_train,y_train)

# %%
pred=lr.predict(x_test)
pred

# %%
print('test score:-',lr.score(x_test,y_test))
print('train score:-',lr.score(x_train,y_train))

# %%
from sklearn.linear_model import LogisticRegression
log =LogisticRegression()
log.fit(x_train,y_train)
print("LogisticRegression training",log.score(x_train,y_train))
print("LogisticRegression testing",log.score(x_test,y_test))

# %% [markdown]
# # # DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.datasets import load_iris
x, y =load_iris(return_X_y=True)
x_train, x_test, y_train, y_test= train_test_split(x, y,test_size=0.2, random_state=42)
dt =DecisionTreeClassifier()
dt.fit(x_train, y_train)

# %%
print('test score:-',dt.score(x_test,y_test))
print('train score:-',dt.score(x_train,y_train))

# %% [markdown]
# # with perameter

# %%
dt.get_params()

# %%
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.datasets import load_iris
x, y =load_iris(return_X_y=True)
x_train, x_test, y_train, y_test= train_test_split(x, y,test_size=0.2, random_state=42)
dt =DecisionTreeClassifier(criterion='entropy', min_samples_split=3, min_samples_leaf=2, random_state=42)
dt.fit(x_train, y_train)

# %%
print('test score:-',dt.score(x_test,y_test))
print('train score:-',dt.score(x_train,y_train))

# %% [markdown]
# #  DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor

from sklearn.datasets import load_iris
x, y =load_iris(return_X_y=True)
x_train, x_test, y_train, y_test= train_test_split(x, y,test_size=0.2, random_state=42)
dt =DecisionTreeRegressor()
dt.fit(x_train, y_train)

# %%
print('test score:-',dt.score(x_test,y_test))
print('train score:-',dt.score(x_train,y_train))

# %% [markdown]
# # with perameter

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.datasets import load_iris
# from sklearn.model_selection import train_test_split
# x, y = load_iris(return_X_y=True)
# x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
# dt = DecisionTreeRegressor(criterion='squared_error',min_samples_split=3,min_samples_leaf=2,random_state=42)
dt.fit(x_train, y_train)

# %%
print("Test Score:", dt.score(x_test, y_test))
print("Train Score:", dt.score(x_train, y_train))

# %%
import joblib
joblib.dump(sv,"bike_load.lp")

# %%
# model = joblib.load(')
