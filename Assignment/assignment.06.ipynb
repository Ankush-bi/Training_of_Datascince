# %% [markdown]
# # Anand International College of Engineering
# # Subject – Data Science with AI&MLops
# ## Date : 24/06/2026
# ## Topic – Matplotlib & Seaborn
# ## Assignment 6:

# %% [markdown]
# 1. Explain Matplotlib and its importance in Data Visualization and Data Science. Also differentiate between the following visualization techniques with suitable use cases: ● Line Plot ● Bar Chart ● Histogram ● Scatter Plot

# %% [markdown]
# 2. Using the dataset below: Student Marks: 45, 56, 67, 78, 89, 90, 72, 60 Tasks: ● Create a bar chart of marks. ● Create a histogram of marks distribution. ● Add chart titles and labels. ● Customize bar width. ● Customize histogram bins. Expected Concepts: ● plt.bar() ● plt.hist() ● bins parameter

# %% [markdown]
# 3. Dataset: Iris Dataset Dataset Link: Iris Dataset (CSV) Tasks: ● Load the dataset using Pandas. ● Display the first five records. ● Create a scatter plot between sepal_length and petal_length. ● Differentiate species using different colors. ● Add a plot title. ● Add X-axis and Y-axis labels. ● Add a legend. Expected Concepts: ● pd.read_csv() ● plt.scatter() ● plt.legend() ● CSV handling with Pandas

# %% [markdown]
#  4. Load the Tips dataset using Seaborn and create a scatter plot showing the relationship between total_bill and tip. Expected Concepts: ● sns.load_dataset() ● sns.scatterplot() ● Data visualization using Seaborn

# %% [markdown]
# 5. Load the Iris dataset using Seaborn and create a pair plot to visualize the relationships between all numerical features. Tasks: ● Differentiate flower species using color. ● Display the pair plot. ● Analyze the relationships between features. Expected Concepts: ● sns.load_dataset() ● sns.pairplot() ● Multivariate data visualization
